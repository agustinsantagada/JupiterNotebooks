# %% [markdown]
# # Research Buenos Aires Real Estate

# %% [markdown]
# ### Primero Importamos las librerias que vamos a utilizar

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. Carga el dataset usando las funcionalidades de Pandas. Imprimir cuántas filas y columnas tiene, y sus cinco primeras instancias.

# %% [markdown]
# ### Primero cargamos el dataset

# %%
df = pd.read_csv ('/Users/Agus/Properati.csv')

# %% [markdown]
# ### Cuantas columnas tiene

# %%
print(len(df.columns))
# Out:
# 19

# %% [markdown]
# ### Cuantas filas tiene

# %%
print(len(df.index))
# Out:
# 146660

# %% [markdown]
# ### Hacemos un count para ver la cantidad de datos

# %%
df.count()
# Out:
# start_date         146660
# end_date           146660
# created_on         146660
# lat                136735
# lon                136701
# l1                 146660
# l2                 146660
# l3                 146660
# rooms              146660
# bedrooms           146660
# bathrooms          140703
# surface_total      126133
# surface_covered    125046
# price              146660
# currency           146660
# title              146660
# description        146660
# property_type      146660
# operation_type     146660
# dtype: int64

# %% [markdown]
# ### Corremos un head para ver si los primeros numeros estan correctos

# %%
df.head()
# Out:
#    start_date    end_date  created_on        lat        lon         l1  \
# 0  2019-10-17  2019-12-23  2019-10-17 -34.605880 -58.384949  Argentina
# 1  2019-10-17  2019-11-21  2019-10-17 -34.624056 -58.412110  Argentina
# 2  2019-10-17  2019-11-01  2019-10-17 -34.593569 -58.427474  Argentina
# 3  2019-10-17  2019-12-23  2019-10-17 -34.581294 -58.436754  Argentina
# 4  2019-10-17  2020-03-11  2019-10-17 -34.914194 -57.938219  Argentina
#
#                        l2             l3  rooms  bedrooms  bathrooms  \
# 0         Capital Federal  San Cristobal    7.0       7.0        2.0
# 1         Capital Federal          Boedo    2.0       1.0        2.0
# 2         Capital Federal        Palermo    2.0       1.0        1.0
# 3         Capital Federal        Palermo    2.0       1.0        1.0
# 4  Bs.As. G.B.A. Zona Sur       La Plata    2.0       1.0        1.0
#
#    surface_total  surface_covered     price currency  \
# 0          140.0            140.0  153000.0      USD
# ...

# %% [markdown]
# ### Corremos un Tail para ver si los primeros numeros estan correctos

# %%
df.tail()
# Out:
#         start_date    end_date  created_on        lat        lon         l1  \
# 146655  2019-07-31  2019-08-13  2019-07-31 -34.816348 -58.181963  Argentina
# 146656  2019-07-31  2019-08-14  2019-07-31 -34.446459 -58.937810  Argentina
# 146657  2019-07-31  2019-08-14  2019-07-31 -34.444633 -58.981606  Argentina
# 146658  2019-07-31  2019-08-14  2019-07-31 -34.444830 -58.981796  Argentina
# 146659  2019-07-31  2019-10-12  2019-07-31 -34.444760 -58.981885  Argentina
#
#                               l2           l3  rooms  bedrooms  bathrooms  \
# 146655    Bs.As. G.B.A. Zona Sur  Berazategui    2.0       1.0        1.0
# 146656  Bs.As. G.B.A. Zona Norte        Pilar    4.0       3.0        2.0
# 146657  Bs.As. G.B.A. Zona Norte        Pilar    1.0       1.0        1.0
# 146658  Bs.As. G.B.A. Zona Norte        Pilar    2.0       1.0        1.0
# 146659  Bs.As. G.B.A. Zona Norte        Pilar    3.0       2.0        1.0
#
#         surface_total  surface_covered     price currency  \
# ...

# %% [markdown]
# 2. **Valores Faltantes**: imprime en pantalla los nombres de las columnas y cuántos valores faltantes hay por columna.

# %% [markdown]
# ### Vemos los valores faltantes de cada columna

# %%
df.isnull().sum()
# Out:
# start_date             0
# end_date               0
# created_on             0
# lat                 9925
# lon                 9959
# l1                     0
# l2                     0
# l3                     0
# rooms                  0
# bedrooms               0
# bathrooms           5957
# surface_total      20527
# surface_covered    21614
# price                  0
# currency               0
# title                  0
# description            0
# property_type          0
# operation_type         0
# dtype: int64

# %% [markdown]
# 3. **Tipos de propiedad**: ¿Cuántos tipos de propiedad hay publicados según este dataset?¿Cuántos instancias por cada tipo de propiedad hay en el dataset? Responde esta pregunta usando las funcionalidad de Pandas y con un gráfico apropiado de Seaborn. **Pistas**: Te puede ser útil googlear cómo rotar las etiquetas del eje x.

# %% [markdown]
# ### Vemos los tipos de propiedades publicados

# %%
df["property_type"].value_counts()
# Out:
# Departamento       107326
# Casa                21521
# PH                  14298
# Lote                 1312
# Oficina               658
# Otro                  374
# Local comercial       325
# Casa de campo         322
# Depósito              265
# Cochera               259
# Name: property_type, dtype: int64

# %% [markdown]
# ### Graficamos las principales categorias

# %%
index = df.property_type.isin(["Departamento","Casa","PH" ])

# %%
sns.countplot(y ='property_type', data = df[index]) 
plt.title('Tipos de propiedades')
plt.xlabel('Número de propiedades')
plt.ylabel('Tipo de propiedad') 
plt.show()

# %% [markdown]
# ### Graficamos el resto de las propiedades

# %%
indexb = df.property_type.isin(["Lote","Oficina","Otro","Local Comercial", "Casa de campo", "Depósito", "Cochera" ])

# %%
plt.figure(figsize=(12, 5))
sns.countplot(y ='property_type', data = df[indexb]) 
plt.title('Tipos de propiedades')
plt.xlabel('Número de propiedades')
plt.ylabel('Tipo de propiedades')
plt.show()

# %% [markdown]
# 4. ¿De qué regiones son las publicaciones? Haz gráficos de barras para las variables `l2` y `l3`. Si te animas, puedes hacer los dos gráficos usando `subplot` de Matplotlib. Dale un tamaño apropiado a la figura para que ambos gráficos se visualicen correctamente.

# %% [markdown]
# ### Analizamos L2 y L3

# %%
df["l2"].value_counts()
# Out:
# Capital Federal             92539
# Bs.As. G.B.A. Zona Norte    24282
# Bs.As. G.B.A. Zona Sur      17173
# Bs.As. G.B.A. Zona Oeste    12666
# Name: l2, dtype: int64

# %%
df["l3"].value_counts()
# Out:
# Palermo            13073
# Tigre               8718
# Almagro             7527
# Belgrano            6935
# Caballito           6650
#                    ...
# Cañuelas             108
# Villa Soldati         69
# Villa Riachuelo       42
# Marcos Paz            35
# Catalinas              5
# Name: l3, Length: 89, dtype: int64

# %% [markdown]
# ### Hacemos el Subplot de L2 y L3

# %%
fig, axarr = plt.subplots(2, 1, figsize=(12, 10))

df['l2'].value_counts().sort_index().plot.bar(
    ax=axarr[0]
)
plt.xticks(rotation = 90)

df['l3'].value_counts().head(20).plot.bar(
    ax=axarr[1]
)

# %% [markdown]
# 5. **Filtrando el Dataset:** A partir de los resultados del punto 3. y 4., selecciona las tres clases más abundantes de tipos de propiedad y la región con más propiedades publicadas. Crea un nuevo Data Frame con aquellas instancias que cumplen con esas condiciones e imprime su `shape`.

# %% [markdown]
# ### Filtramos El DS

# %%
filter1 = df["property_type"].isin(["Departamento","Casa","PH"]) 
filter2 = df["l2"].isin(["Capital Federal"])

# %%
df2 = df[filter1 & filter2]

# %%
df2
# Out:
#         start_date    end_date  created_on        lat        lon         l1  \
# 0       2019-10-17  2019-12-23  2019-10-17 -34.605880 -58.384949  Argentina
# 1       2019-10-17  2019-11-21  2019-10-17 -34.624056 -58.412110  Argentina
# 2       2019-10-17  2019-11-01  2019-10-17 -34.593569 -58.427474  Argentina
# 3       2019-10-17  2019-12-23  2019-10-17 -34.581294 -58.436754  Argentina
# 5       2019-10-17  2019-11-01  2019-10-17 -34.593779 -58.441239  Argentina
# ...            ...         ...         ...        ...        ...        ...
# 146554  2019-07-31  2019-08-14  2019-07-31 -34.585355 -58.427194  Argentina
# 146555  2019-07-31  2019-08-14  2019-07-31 -34.585355 -58.427194  Argentina
# 146556  2019-07-31  2020-01-17  2019-07-31 -34.584134 -58.436389  Argentina
# 146557  2019-07-31  2019-08-23  2019-07-31 -34.583995 -58.417645  Argentina
# 146558  2019-07-31  2020-01-17  2019-07-31        NaN        NaN  Argentina
#
# ...

# %%
df2.shape
# Out:
# (91485, 19)

# %% [markdown]
# ### El checkpoint nos da correctamente

# %% [markdown]
# **Checkpoint:** deberías tener un dataset con 91485 instacias, 19 columnas.
#
# 6. **Distribuciones y relaciones de a pares:** Estudia la distribución y las relaciones de a pares de las variables `rooms`, `bedrooms`, `bathrooms`, `surface_total`, `surface_covered`, `price` para cada tipo de propiedad. Para ello, ten en cuenta:
#     1. Obtiene estadísticos que te sirvan para tener una primera idea de los valores que abarcan estas variables. ¿Cuáles crees que toman valores que tal vez no tengan mucho sentido?
#     1. Algunas instancias tienen valores de superficie (`surface_total`) muy grandes y dificultan la correcta visualización. Estudia la distribución de esa variable y filtra por un valor razonable que te permita obtener gráficos comprensibles. Puede ser útil un boxplot para determinar un rango razonable.
#     1. Lo mismo ocurre con valores de superficie total muy chico.
#     1. Las propiedades no pueden tener `surface_covered` mayor a `surface_total`. Si eso sucede, debes filtrar esas instancias.
#     1. El rango de precios que toman las propiedades es muy amplio. Estudia la distribución de esa variable y filtra por un valor razonable que te permita obtener gráficos comprensibles. Puede ser útil un boxplot para determinar un rango razonable.
#     1. Una vez filtrado el dataset, puedes utilizar la función `pairplot` de Seaborn.

# %% [markdown]
# ### Analizamos la distribución de Surface_total

# %%
df['surface_total'].quantile([ 0.01, .015, .02, .025, .3, .4, .5, .6, .7, .8, .85, .9, .93, .95, .98])
# Out:
# 0.010     27.0
# 0.015     30.0
# 0.020     30.0
# 0.025     32.0
# 0.300     56.0
# 0.400     67.0
# 0.500     78.0
# 0.600     95.0
# 0.700    120.0
# 0.800    168.0
# 0.850    210.0
# 0.900    289.0
# 0.930    364.0
# 0.950    473.0
# 0.980    941.0
# Name: surface_total, dtype: float64

# %% [markdown]
# ### Analizamos la distribución de Surface_covered

# %%
df['surface_covered'].quantile([ 0.01, .015, .02, .025, .3, .4, .5, .6, .7, .8, .85, .9, .93, .95, .98, 1])
# Out:
# 0.010        25.0
# 0.015        27.0
# 0.020        28.0
# 0.025        30.0
# 0.300        50.0
# 0.400        58.0
# 0.500        68.0
# 0.600        80.0
# 0.700        96.0
# 0.800       123.0
# 0.850       146.0
# 0.900       180.0
# 0.930       209.0
# 0.950       241.0
# 0.980       345.0
# 1.000    126062.0
# Name: surface_covered, dtype: float64

# %% [markdown]
# ### Analizamos la distribución de Prices

# %%
df['price'].quantile([ 0.01, .015, .02, .025, .3, .4, .5, .6, .7, .8, .85, .9, .93, .95, .98, 1])
# Out:
# 0.010       45693.0
# 0.015       50000.0
# 0.020       54900.0
# 0.025       57000.0
# 0.300      120000.0
# 0.400      143000.0
# 0.500      166000.0
# 0.600      198000.0
# 0.700      240000.0
# 0.800      298000.0
# 0.850      350000.0
# 0.900      430000.0
# 0.930      520000.0
# 0.950      620000.0
# 0.980     1000000.0
# 1.000    32434232.0
# Name: price, dtype: float64

# %% [markdown]
# ### Procedemos a hacer una mascara para filtrar los valores extremos

# %%
df3 = df.where((df['surface_total'] > df['surface_covered']))

# %%
df4 = df3.where((df3['price'] < 600000) & (df3['rooms'] < 10) & (df3['surface_covered'] < 500) & (df3['bathrooms'] < 10))

# %%
sns.pairplot(df4,vars=['rooms', 'bedrooms', 'bathrooms', 'surface_total', 'surface_covered', 'price'], hue="l2" )

# %% [markdown]
# ### Analizamos las superficies cubiertas

# %%
sns.pairplot(df4,vars=['rooms', 'bedrooms', 'bathrooms', 'surface_total', 'surface_covered', 'price'], hue="property_type" )

# %% [markdown]
# ### Analizamos los cuartos y su precio

# %%
plt.figure(figsize=(15, 5))
sns.barplot(data = df4, x = "rooms", y = "price")

# %% [markdown]
# ### Analizamos las habitaciones y su precio

# %%
plt.figure(figsize=(15, 5))
sns.barplot(data = df4, x = "bedrooms", y = "price" )

# %% [markdown]
# ### Analizamos los baños y su precio

# %%
plt.figure(figsize=(15, 5))
sns.barplot(data = df4, x = "bathrooms", y = "price")

# %%
mascara = np.logical_and(df4.bedrooms <= 7, df4.price < 600000)
df4[mascara]
# Out:
#         start_date    end_date  created_on         l1               l2  \
# 0       2019-10-17  2019-12-23  2019-10-17  Argentina  Capital Federal
# 1       2019-10-17  2019-11-21  2019-10-17  Argentina  Capital Federal
# 2       2019-10-17  2019-11-01  2019-10-17  Argentina  Capital Federal
# 3       2019-10-17  2019-12-23  2019-10-17  Argentina  Capital Federal
# 5       2019-10-17  2019-11-01  2019-10-17  Argentina  Capital Federal
# ...            ...         ...         ...        ...              ...
# 146552  2019-07-31  2019-09-04  2019-07-31  Argentina  Capital Federal
# 146554  2019-07-31  2019-08-14  2019-07-31  Argentina  Capital Federal
# 146555  2019-07-31  2019-08-14  2019-07-31  Argentina  Capital Federal
# 146556  2019-07-31  2020-01-17  2019-07-31  Argentina  Capital Federal
# 146557  2019-07-31  2019-08-23  2019-07-31  Argentina  Capital Federal
#
#                    l3  rooms  bedrooms  bathrooms  surface_total  \
# ...

# %% [markdown]
# ### Analizamos el precio y las habitaciones de descanso para encontrar la media

# %%
plt.figure(figsize=(12, 5))
ax = sns.boxplot(data = df4[mascara], x = "bedrooms", y = "price")
ax.set(xlabel="Habitación de descanso", ylabel = "Precio")
# Out:
# [Text(0, 0.5, 'Precio'), Text(0.5, 0, 'Habitación de descanso')]

# %% [markdown]
# #### La conclusión del grafico es que mas de 4 habitaciones no conviene consutrir ya que es el valor medio mas alto

# %% [markdown]
# ### Analizamos el precio en relación con los baños

# %%
plt.figure(figsize=(12, 5))
ax =chart = sns.boxplot(data = df4[mascara], x = "bathrooms", y = "price")
ax.set(xlabel="Cantidad de baños", ylabel = "Precio")
# Out:
# [Text(0, 0.5, 'Precio'), Text(0.5, 0, 'Cantidad de baños')]

# %% [markdown]
# #### La conclución del gráfico es que mas de 5 baños no conviene contruir ya que alcanza el valor y media mas alta

# %%
mascara2 = np.logical_and(df4.rooms <= 10, df4.price > (120000 < 600000))
df4[mascara2]
# Out:
#         start_date    end_date  created_on        lat        lon         l1  \
# 1       2019-10-17  2019-11-21  2019-10-17 -34.624056 -58.412110  Argentina
# 3       2019-10-17  2019-12-23  2019-10-17 -34.581294 -58.436754  Argentina
# 4       2019-10-17  2020-03-11  2019-10-17 -34.914194 -57.938219  Argentina
# 8       2019-10-17  2019-12-23  2019-10-17 -34.639598 -58.419612  Argentina
# 9       2019-10-17  2019-12-23  2019-10-17 -34.639598 -58.419612  Argentina
# ...            ...         ...         ...        ...        ...        ...
# 146646  2019-07-31  2019-09-04  2019-07-31 -34.444630 -58.620901  Argentina
# 146654  2019-07-31  2019-11-02  2019-07-31 -34.602389 -58.591058  Argentina
# 146655  2019-07-31  2019-08-13  2019-07-31 -34.816348 -58.181963  Argentina
# 146656  2019-07-31  2019-08-14  2019-07-31 -34.446459 -58.937810  Argentina
# 146657  2019-07-31  2019-08-14  2019-07-31 -34.444633 -58.981606  Argentina
#
# ...

# %% [markdown]
# 7. **Correlaciones:** Estudia la correlación entre las variables `rooms`, `bedrooms`, `bathrooms`, `surface_total`, `surface_covered`, `price`. ¿Cuáles son las mejores variables para predecir el precio?¿Qué diferencias encuentras según cada tipo de propiedad?

# %%
df4= df2.drop(['lat', 'lon'], axis=1)

# %%
df4.corr()
# Out:
#                     rooms  bedrooms  bathrooms  surface_total  \
# rooms            1.000000  0.927300   0.603174       0.064774
# bedrooms         0.927300  1.000000   0.603968       0.064468
# bathrooms        0.603174  0.603968   1.000000       0.056524
# surface_total    0.064774  0.064468   0.056524       1.000000
# surface_covered  0.066757  0.066174   0.058192       0.770742
# price            0.448318  0.413555   0.587724       0.049071
#
#                  surface_covered     price
# rooms                   0.066757  0.448318
# bedrooms                0.066174  0.413555
# bathrooms               0.058192  0.587724
# surface_total           0.770742  0.049071
# surface_covered         1.000000  0.054534
# price                   0.054534  1.000000

# %% [markdown]
# ### Vemos que las correlaciones dan como resultado:
# El precio va de consiguiente con la cantidad de baños, ya que es el sector
# mas caro de construir luego de la cocina; entonces encarece la propiedad.
#
# La cantidad de baños no deben ser mas de 5 luego de este numero,
# no se capitabiliza de la misma forma.
#
# La otra variable logica es la superficie cubierta, es la segunda variable
# a encarecer el precio luego de los baños

# %% [markdown]
# ### Filtramos las principales variables que consideramos importantes

# %%
sup = ['l3','rooms','bedrooms', 'bathrooms', 'price']
df5 = df4.groupby('l3')[sup].mean()

# %% [markdown]
# ### Las agrupamos por barrio y las ordenamos por precio

# %%
df5.sort_values(by=['price'], inplace=True, ascending=False)
df5.head()
# Out:
#                   rooms  bedrooms  bathrooms          price
# l3
# Puerto Madero  3.053265  2.054983   2.720783  985202.209622
# Las Cañitas    3.185279  2.184010   2.235294  469488.154822
# Recoleta       3.432782  2.236156   1.808724  410003.824502
# Belgrano       3.165067  2.138598   1.900441  377029.863438
# Palermo        2.951488  1.921504   1.619218  354744.484662

# %% [markdown]
# ### De este dataset podemos observar cuales son los barrios mas caros.
# Los ordenamos de mayor a menor y nos da como resultado
# Puerto Madero / Las cañitas /  Recoleta

# %% [markdown]
# ### Si hacemos el el grupo sin filtro nos da el siguiente resultado

# %%
sup = ['l3','rooms','bedrooms', 'bathrooms', 'price']
df7 = df.groupby('l3')[sup].mean()

# %%
df7.sort_values(by=['price'], inplace=True, ascending=False)
df7
# Out:
#                     rooms  bedrooms  bathrooms          price
# l3
# Puerto Madero    3.051224  2.052362   2.714940  984679.031303
# Villa Riachuelo  3.547619  2.428571   1.550000  535988.071429
# Las Cañitas      3.182510  2.181242   2.235294  469045.204056
# Recoleta         3.440088  2.242860   1.811759  410252.230184
# Belgrano         3.157174  2.130353   1.901373  376293.661283
# ...                   ...       ...        ...            ...
# Boca             3.079772  2.031339   1.273529  128428.273504
# Avellaneda       3.083942  2.032847   1.377513  127272.403650
# Villa Soldati    3.898551  2.695652   1.384615  122472.463768
# Constitución     2.525316  1.630802   1.184946  104534.073840
# José C Paz       3.271777  2.195122   1.360424   91501.874564
#
# [89 rows x 4 columns]

# %% [markdown]
# ### Esto significa que villa riachuelo figura en el segundo lugar, pero es un dato erroneo.
#
# La diferencia es que no tiene superficies construidas grandes.
# Figura en dicho puesto por grandes parcelas.

# %%
sup = ['l3','surface_covered','rooms','bedrooms', 'bathrooms', 'price']
df8 = df.groupby('bedrooms')[sup].mean()

# %%
df8.sort_values(by=['price'], inplace=True, ascending=False)
df8
# Out:
#           surface_covered      rooms  bedrooms  bathrooms          price
# bedrooms
# 8.0            375.000000  10.323077       8.0   3.885246  637107.692308
# 10.0           319.000000  11.304348      10.0   4.521739  616869.565217
# 5.0            404.874855   6.540984       5.0   3.239186  574828.207811
# 15.0           434.166667  17.000000      15.0   4.500000  516666.666667
# 6.0            302.371575   7.464844       6.0   3.534226  511624.088542
# 14.0           397.625000  17.750000      14.0   5.500000  499250.000000
# 4.0            283.787830   5.402952       4.0   2.724224  485669.642873
# 9.0            457.800000  10.718750       9.0   5.066667  481431.250000
# 7.0            293.538462   8.290698       7.0   3.450593  459077.519380
# 13.0           467.500000  14.166667      13.0   8.166667  444500.000000
# 12.0           406.812500  14.187500      12.0   6.375000  440250.000000
# 3.0            155.777652   4.198544       3.0   2.122528  357692.486792
# ...

# %%
corr = df4.drop(columns = 'l2').corr()
plt.figure(figsize=(12,12))
sns.heatmap(corr, cbar = True,  square = True, annot=True, fmt= '.1f',annot_kws={'size': 10},
           xticklabels=df4.drop(columns = ['start_date','created_on','end_date','l1','l2','l3','surface_total','currency','description','property_type','operation_type']).columns, 
           yticklabels=df4.drop(columns = ['start_date','created_on','end_date','l1','l2','l3','surface_total','currency','description','property_type','operation_type']).columns,
           cmap= 'coolwarm')
plt.xticks(rotation = 90)
plt.yticks(rotation = 0)
plt.show()

# %% [markdown]
# Aca el grafico nos muestra que el precio de las propiedades siempre esta dado primero por el siguiente orden:
#     1.ambientes
#     2.habitaciones
#     3.Superficie Cubierta
#     4.Baños

# %% [markdown]
# ### Filtramos el dataset

# %%
df_mach_learn =df[(df["property_type"] == "PH") | (df["property_type"] == "Casa") | (df["property_type"] == "Departamento") ]
df_mach_learn = df_mach_learn[(df_mach_learn.l2 == "Capital Federal")]
df_mach_learn = df_mach_learn[(df_mach_learn.surface_total >= 15)]
df_mach_learn = df_mach_learn[(df_mach_learn.surface_total <= 1000)]
df_mach_learn = df_mach_learn[(df_mach_learn.price <= 4000000)]
df_mach_learn = df_mach_learn[["rooms","bedrooms","bathrooms","surface_total","surface_covered","price"]]
df_mach_learn.isna().sum()
df_mach_learn = df_mach_learn.dropna()
df_mach_learn.shape
# Out:
# (81019, 6)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Definimos las variables

# %%
X=df_mach_learn[['surface_total']]
y=df_mach_learn['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3 , random_state=42)

# %% [markdown]
# ### Entrenamos el árbol

# %%
tree=DecisionTreeRegressor(max_depth=3,random_state=1)
tree.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=3,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=1, splitter='best')

# %%
y_train_pred=tree.predict(X_train)

# %%
y_train_pred
# Out:
# array([198256.86582781, 122513.09719827, 198256.86582781, ...,
#        198256.86582781, 198256.86582781, 122513.09719827])

# %%
y_test_pred=tree.predict(X_test)

# %%
y_test_pred
# Out:
# array([198256.86582781, 122513.09719827, 398436.14240915, ...,
#        398436.14240915, 834216.30033711, 198256.86582781])

# %%
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_pred))
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))
print(rmse_train) 
print(rmse_test)
# Out:
# 213213.8027447749
# 216939.535641816

# %%
from sklearn.neighbors import KNeighborsRegressor

# %% [markdown]
# ### Entrenamos vecinos cercanos

# %%
knn = KNeighborsRegressor(n_neighbors=5)
knn.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                     weights='uniform')

# %%
y_pred = knn.predict(X_train)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor

linear_model = LinearRegression()
tree_regressor = DecisionTreeRegressor(max_depth=3, random_state=42)
knn_regressor = KNeighborsRegressor(n_neighbors=5)

# %%
linear_model.fit(X_train, y_train)
tree_regressor.fit(X_train, y_train)
knn_regressor.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                     weights='uniform')

# %%
k_vecinos = print(linear_model.coef_, linear_model.intercept_)
# Out:
# [2630.4146957] 13037.407671383029

# %% [markdown]
# ### Gráficamos los tres modelos

# %%
plt.figure(figsize = (12,4))

plt.subplot(1,3,1)
plt.scatter(X,y, s = 2)
#plt.plot(X, y_pred, '--',label ='Curva Teórica', c = 'r')
plt.plot(X,linear_model.predict(X),label ='Regresion Lineal', c = 'g')
plt.xlabel('Metro Cuadrados')
plt.ylabel('Precio')
plt.legend()


plt.subplot(1,3,2)
plt.scatter(X,y, s = 2)
#plt.plot(X, y_pred, '--',label ='Curva Teórica', c = 'r')
plt.plot(X,tree_regressor.predict(X),label ='Árbol de Decisión', c = 'g')

plt.xlabel('Metro Cuadrados')
plt.ylabel('Precio')
plt.legend()

plt.subplot(1,3,3)
plt.scatter(X,y, s = 2)
#plt.plot(X, y_pred, '--',label ='Curva Teórica', c = 'r')
plt.plot(X,knn_regressor.predict(X),label ='knn', c = 'g')

plt.xlabel('Metro Cuadrados')
plt.ylabel('Precio')
plt.legend('Vecinos Cercanos')

plt.tight_layout()
plt.show()

# %% [markdown]
# ####Elegimos hacer los tres tipos de gráficos para poder comparar que predicciones nos dan mejores resultados. Vemos como conclución que el mejor grafico responde a Vecinos cercanos ya que nos da un resultado mas apróximado que Regresión lineal y Árbol de decisión

# %% [markdown]
# ### Hacemos un arbol de decisión

# %%
from sklearn import tree
plt.figure(figsize=(15, 10))
if tree_regressor.max_depth < 4:
    plt.figure(figsize = (20,15))
    tree.plot_tree(tree_regressor, filled = True)
   
    plt.show()

# %% [markdown]
# Como conclusión del grafico vemos que 60 mts cuadrados cubiertos rondan los 150 mil dólares y tienen un rango diferencial de 70 mil dólares
# Por el otro extremo vemos que lso departamentos de 400 mts cuadrados rondan los 900 mil dólares y tienen un rango diferencial de 450 mil dólres

# %% [markdown]
# ### Vamos a analizar el error del árbol de dicisión y vecinos cercanos

# %%
k_nei=[1,2,3,4,5,6,7,8,9] 
k_nei_train_error=[]
k_nei_test_error=[]

for k in k_nei:   
    nei=KNeighborsRegressor(n_neighbors=k)
    nei.fit(X_train,y_train)

    y_train_pred_k=nei.predict(X_train)
    y_test_pred_k=nei.predict(X_test)

    rmse_train = np.sqrt(mean_squared_error(y_train, y_train_pred_k))
    rmse_test= np.sqrt(mean_squared_error(y_test, y_test_pred_k))
    print(rmse_train) 
    print(rmse_test)
    
    k_nei_train_error.append(rmse_train)
    k_nei_test_error.append(rmse_test)
    
    print("\nCon un depth de:", k)
    print(f'Raíz del error cuadrático medio en Train: {rmse_train}')
    print(f'Raíz del error cuadrático medio en Test: {rmse_test}')
# Out:
# 241702.83705670893
# 263563.6286480237
#
# Con un depth de: 1
# Raíz del error cuadrático medio en Train: 241702.83705670893
# Raíz del error cuadrático medio en Test: 263563.6286480237
# 210791.22684567072
# 230815.7860779692
#
# Con un depth de: 2
# Raíz del error cuadrático medio en Train: 210791.22684567072
# Raíz del error cuadrático medio en Test: 230815.7860779692
# 199409.30621384678
# 219956.18250582382
#
# Con un depth de: 3
# Raíz del error cuadrático medio en Train: 199409.30621384678
# Raíz del error cuadrático medio en Test: 219956.18250582382
# 196542.92977763028
# 217631.658537393
#
# Con un depth de: 4
# Raíz del error cuadrático medio en Train: 196542.92977763028
# Raíz del error cuadrático medio en Test: 217631.658537393
# 196038.14265990336
# 214331.4120497579
#
# Con un depth de: 5
# Raíz del error cuadrático medio en Train: 196038.14265990336
# Raíz del error cuadrático medio en Test: 214331.4120497579
# 194463.51402021828
# 212681.0239572703
#
# ...

# %%
k_tree=[1,2,3,4,5,6,7,8,9] 
k_tree_train_error=[]
k_tree_test_error=[]

for k in k_tree:   
    tree=DecisionTreeRegressor(max_depth=k,random_state=1)
    tree.fit(X_train,y_train)

    y_train_pred=tree.predict(X_train)
    y_test_pred=tree.predict(X_test)

    rmse_train = np.sqrt(mean_squared_error(y_train, y_train_pred))
    rmse_test= np.sqrt(mean_squared_error(y_test, y_test_pred))
    print(rmse_train) 
    print(rmse_test)
    
    k_tree_train_error.append(rmse_train)
    k_tree_test_error.append(rmse_test)
    
    print("\nCon un depth de:", k)
    print(f'Raíz del error cuadrático medio en Train: {rmse_train}')
    print(f'Raíz del error cuadrático medio en Test: {rmse_test}')
# Out:
# 241977.38590562774
# 246824.56631912984
#
# Con un depth de: 1
# Raíz del error cuadrático medio en Train: 241977.38590562774
# Raíz del error cuadrático medio en Test: 246824.56631912984
# 221714.1717111161
# 225947.7329780329
#
# Con un depth de: 2
# Raíz del error cuadrático medio en Train: 221714.1717111161
# Raíz del error cuadrático medio en Test: 225947.7329780329
# 213213.8027447749
# 216939.535641816
#
# Con un depth de: 3
# Raíz del error cuadrático medio en Train: 213213.8027447749
# Raíz del error cuadrático medio en Test: 216939.535641816
# 210357.25111878265
# 213541.81592936424
#
# Con un depth de: 4
# Raíz del error cuadrático medio en Train: 210357.25111878265
# Raíz del error cuadrático medio en Test: 213541.81592936424
# 208079.40721421185
# 212013.33401471542
#
# Con un depth de: 5
# Raíz del error cuadrático medio en Train: 208079.40721421185
# Raíz del error cuadrático medio en Test: 212013.33401471542
# 201778.9511497717
# 207976.6602744634
#
# ...

# %% [markdown]
# ## RMSE
#
# Analizamos los valores con   RMSE ya que es la mejor medida frente  MAE debido a que nos da la diferencia entre la predicción y el valor real del error

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True,figsize=(15,10))

ax1.plot(k_tree,k_tree_train_error,'o-',label='train')
ax1.plot(k_tree,k_tree_test_error,'o-',label='test')
ax2.plot(k_nei,k_nei_train_error,'o-',label='train')
ax2.plot(k_nei,k_nei_test_error,'o-',label='test')

plt.legend()
ax1.set_title("Modelo de arbol de decision", size =14)
ax2.set_title("Modelo de vecinos cercanos", size =14)
ax1.set_xlabel("N° ramas")
ax2.set_xlabel("N° vecinos")
ax1.set_ylabel("Error(En USD)")
ax2.set_ylabel("Error(En USD)")
plt.show()

# %% [markdown]
# #### Vemos que el resultado mas conveniente es el de arbol de decisión pero la diferencia de acierto es de 200 mil dólares, debido al grango de precios de 4 millones.

# %% [markdown]
# # Infomación que no usamos
# Algo que nos puede ser muy util, son las coordenadas ya que podriamos buscar información sobre los medios de transporte y cruzar los datos con las coordenadas y obtener mejores resultados de precios para poder comprender mejor el valor de las propiedades ya que si bien obtnemos los precios de los barrios por macro podemos obetener resultados mas micro con este tipo de información.
#
# Algo poco relevante en el dataset, es el titulo y la descripcion, ya que no proporciona nada de valor y no puede agruparse para ser analizada.

# %% [markdown]
# ___

# %% [markdown]
# ## Conclución Final
#
# Los mas caros son los Depositos, debido a su gran tamaño;
# pero es una excelente inversión para el futuro de los negocios de ecommerce.
#
# Como vivienda solo sirve construir como máximos 6 habitaciones y 5 baños
# ya despues de ello, no se genera rentabilidad.
#
# El grafico del arbol nos dio como resultado que el menor gap se encuentra en
# los departamentos mas chicos lo cual es bueno para consutruir y vender rapido
# ya que hay menor diferencia de precio comparando con superficies grandes.
#
# El barrio mas rentable para construir es Puerto Madero ya que es donde mas se
# despega del resto a nivel precio.
#
# Gracias!!!
